# %% [raw]
# Telecom Churn Prediction by stackQest

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns # For creating plots
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv(r"C:\Users\Lokanathswami\Downloads\telco-customer-churn-on-icp4d-master\data\Telco-Customer-Churn.csv")
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# Display Setting  
pd.set_option('display.max_columns', None)   # for columns
#pd.set_option('display.max_rows', None)     # For Rows

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
# Dropping Column
df.drop(['customerID'],axis=1,inplace=True)# Pass list

# %% [raw]
# XGBoost doesn't care for blank spaces in lebels which are present in columns bcz we using one hot encoding.But if we want to draw a tree then we can't have any whitespace between labels.XGBoost know how to handle missing data.we can use 0 fro missing data then also XGboost does well job.
# XGBoost only allows int,flot or boolean data type.
# we are removing spaces from entire df to print out nice tree only.

# %% [raw]
# # Text Preprocessing  Removing whitespaces between labels prsent in column
# import re
#
# df['column Name'].replace(' ','_',regex=True,inplace=True)# Search & Replace, ' ' one blank space,'  ' two blank space,'' no sp
# df.replace(' ','_',regex=True,inplace=True) # for entire dataframe i.e for each column name & Labels in that df

# %% [raw]
# # Text Preprocessing  Removing whitespaces between the column Names
# import re
# df.columns=df.columns.str.replace(' ','_')  # only for column Names

# %% [raw]
# # Displaying first 10 unique labels names from column
# df['column Name'].unique()  # Display all unique labels
# df['column Name'].unique()[0:10]  # Display only 10 unique labels from that column

# %%
# Identifying Missing value
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [raw]
# Checking missing value for object type column is very important.object means it contains mixture of text data like Yes or No.also Numbers.
# But sometimes it contains ? which is nothing but missing value.hence check for unique values for each object type column.

# %%
df['TotalCharges'].unique()
# Out:
# array(['29.85', '1889.5', '108.15', ..., '346.45', '306.6', '6844.5'],
#       dtype=object)

# %% [raw]
# # Converting object type to Numeric type
# df['same column Name']=pd.to_numeric(df['same column Name'] )

# %% [raw]
# Actually it looks bunch of Numbers but datatpe is object.If we try to convert object to Numeric it gives error.bcz it contains something else like blank spaces or characters like ?,- etc

# %%
# Finding Blank rows from the columns 'Totalcharges'
# df.loc[]   return the df
df.loc[df['TotalCharges']==' ']   # condition df['TotalCharges']==' '
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female              0     Yes        Yes       0           No
# 753     Male              0      No        Yes       0          Yes
# 936   Female              0     Yes        Yes       0          Yes
# 1082    Male              0     Yes        Yes       0          Yes
# 1340  Female              0     Yes        Yes       0           No
# 3331    Male              0     Yes        Yes       0          Yes
# 3826    Male              0     Yes        Yes       0          Yes
# 4380  Female              0     Yes        Yes       0          Yes
# 5218    Male              0     Yes        Yes       0          Yes
# 6670  Female              0     Yes        Yes       0          Yes
# 6754    Male              0      No        Yes       0          Yes
#
#          MultipleLines InternetService       OnlineSecurity  \
# 488   No phone service             DSL                  Yes
# ...

# %%
# Checking No of rows missing in that column
len(df.loc[df['TotalCharges']==' '])
# Out:
# 11

# %%
# finding & replacing column values
# filling all blank spaces with 0 
#df.loc[ (for which values), 'which column']= put value
df.loc[(df['TotalCharges']==' '),'TotalCharges']=0

# %%
len(df.loc[df['TotalCharges']==' '])
# Out:
# 0

# %%
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
# Converting datatype
# Totalcharges still datatype is object hence change to numeric
df['TotalCharges']=pd.to_numeric(df['TotalCharges'] )

# %%
# Verify datatype of 'TotalCharges'
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# Churn                object
# dtype: object

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
# Replace a single value with a new value for an individual DataFrame column:
# df['column name'] = df['column name'].replace(['old value'],'new value')

# Replace multiple values with multiple new values for an individual DataFrame column:
df['Churn'] = df['Churn'].replace(['No','Yes'],['0','1'])

# %%
# Churn datatype is object hence change to numeric
df['Churn']=pd.to_numeric(df['Churn'] )

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
# Spilitting the dataset
X=df.drop('Churn',axis=1).copy()
Y=df['Churn'].copy()

# %%
X.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
Y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Churn, dtype: int64

# %%
X.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges        float64
# dtype: object

# %%
# Selecting only object type columns
cat_columns_df=df.select_dtypes(include=['object']) # Return the dataframe contains only object type columns
cat_columns_df.head()
# Out:
#    gender Partner Dependents PhoneService     MultipleLines InternetService  \
# 0  Female     Yes         No           No  No phone service             DSL
# 1    Male      No         No          Yes                No             DSL
# 2    Male      No         No          Yes                No             DSL
# 3    Male      No         No           No  No phone service             DSL
# 4  Female      No         No          Yes                No     Fiber optic
#
#   OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# 0             No          Yes               No          No          No
# 1            Yes           No              Yes          No          No
# 2            Yes          Yes               No          No          No
# 3            Yes           No              Yes         Yes          No
# 4             No           No               No          No          No
#
#   StreamingMovies        Contract PaperlessBilling              PaymentMethod
# ...

# %%
# Extracting object type column names only
list(cat_columns_df)
# Out:
# ['gender',
#  'Partner',
#  'Dependents',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod']

# %%
object_columns=list(cat_columns_df)

# %%
# Treating categorical data as a Contineous by one hot encoding
X_encoded=pd.get_dummies(X,columns=object_columns,drop_first=True)

# %%
X_encoded.head()
# Out:
#    SeniorCitizen  tenure  MonthlyCharges  TotalCharges  gender_Male  \
# 0              0       1           29.85         29.85            0
# 1              0      34           56.95       1889.50            1
# 2              0       2           53.85        108.15            1
# 3              0      45           42.30       1840.75            1
# 4              0       2           70.70        151.65            0
#
#    Partner_Yes  Dependents_Yes  PhoneService_Yes  \
# 0            1               0                 0
# 1            0               0                 1
# 2            0               0                 1
# 3            0               0                 0
# 4            0               0                 1
#
#    MultipleLines_No phone service  MultipleLines_Yes  \
# 0                               1                  0
# 1                               0                  0
# 2                               0                  0
# ...

# %%
X_encoded.shape
# Out:
# (7043, 30)

# %% [markdown]
# # Building a Priliminary XGBoost model

# %%
# Checking Balanced or imbalanced dataset
# % People left
sum(Y)/len(Y)
# Out:
# 0.2653698707936959

# %%
# Checking Unique values in Y df
# df['B'].value_counts() # For Column values
#df.value_counts() # For any Df
#df_name.nunique() # countFor any df 1D
Y.value_counts()
# Out:
# 0    5174
# 1    1869
# Name: Churn, dtype: int64

# %%
# % people left
1869/(5174+1869)
# Out:
# 0.2653698707936959

# %% [raw]
# only 27% people left the company.Because of this,when we split the data into training and testing,we will split using stratification in order to maintain the same percentage of people who left the company in both the training set & testing set.

# %%
#Splitting The Datsets train test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X_encoded, Y, random_state=42,stratify=Y) #stratify=Y works as expected

# %%
# Checking balnced or not
sum(y_train)/len(y_train),sum(y_test)/len(y_test)
# Out:
# (0.2654297614539947, 0.26519023282226006)

# %% [raw]
# y_train & y_test have the same percentage of people that left the company.

# %%
import xgboost as xgb
clf_xgb=xgb.XGBClassifier(objective='binary:logistic',missing=None,seed=42)  # missing=None -specified ur missing data '?' or 0
clf_xgb.fit(x_train,y_train,verbose=True,early_stopping_rounds=10,eval_metric='aucpr',eval_set=[(x_test,y_test)])
# seed=42 used for same result
#eval_metric 
#eval_set  based on testing dataset
# Out:
# [0]	validation_0-aucpr:0.596821
# Will train until validation_0-aucpr hasn't improved in 10 rounds.
# [1]	validation_0-aucpr:0.596821
# [2]	validation_0-aucpr:0.616819
# [3]	validation_0-aucpr:0.622354
# [4]	validation_0-aucpr:0.625807
# [5]	validation_0-aucpr:0.63018
# [6]	validation_0-aucpr:0.628641
# [7]	validation_0-aucpr:0.630951
# [8]	validation_0-aucpr:0.630587
# [9]	validation_0-aucpr:0.636708
# [10]	validation_0-aucpr:0.637894
# [11]	validation_0-aucpr:0.639997
# [12]	validation_0-aucpr:0.638768
# [13]	validation_0-aucpr:0.640351
# [14]	validation_0-aucpr:0.643511
# [15]	validation_0-aucpr:0.642886
# [16]	validation_0-aucpr:0.643331
# [17]	validation_0-aucpr:0.643869
# [18]	validation_0-aucpr:0.644045
# [19]	validation_0-aucpr:0.644829
# [20]	validation_0-aucpr:0.644679
# [21]	validation_0-aucpr:0.644612
# [22]	validation_0-aucpr:0.643908
# [23]	validation_0-aucpr:0.643668
# [24]	validation_0-aucpr:0.645144
# [25]	validation_0-aucpr:0.646713
# ...

# %% [raw]
# # Above are the results of each tree
# # finally we stop by building 68 trees and privious 10 trees didnot improve the classification accuracy hence we stopping at best iteration i.e 58th tree

# %%
# Checking performance on testing dataset
#plotting Confusion Matrix for test dataset
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(clf_xgb, x_test, y_test,values_format='d',display_labels=['Did not Left','Left'])

# %%
1182/(1182+112)*100
# Out:
# 91.34466769706336

# %%
224/(224+243)
# Out:
# 0.4796573875802998

# %% [raw]
# 91 % correctly classified as Did not left & 48 % correctlyrrectly classified as left
# So model not performed well.
# XGBoost has a parameter 'scale_pos_weight' that helps with imbalanced data.Try to improve predictions using Cross Validation to optimize the parameters'. we are increaing penalty to correctly classify.

# %% [markdown]
# # Optimizing Parameters using cross validation and GridSearch()

# %%
# Round 1
param_grid={
            'max_depth':[3,4,5],
            'learning_rate':[0.1,0.01,0.05],
            'gamma':[0,0.25,1],
            'reg_lambda':[0,1.0,10.0],
            'scale_pos_weight':[1,3,5]
               }

from sklearn.model_selection import GridSearchCV
optimal_params=GridSearchCV(estimator=xgb.XGBClassifier(objective='binary:logistic',seed=42,subsample=0.9,colsample_bytree=0.5),
                            param_grid=param_grid,
                            scoring='roc_auc',
                            verbose=0,
                            n_jobs=10,
                            cv=3
                            )

optimal_params.fit(x_train,y_train,verbose=False,early_stopping_rounds=10,eval_metric='auc',eval_set=[(x_test,y_test)])
# Out:
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(colsample_bytree=0.5, seed=42,
#                                      subsample=0.9),
#              n_jobs=10,
#              param_grid={'gamma': [0, 0.25, 1],
#                          'learning_rate': [0.1, 0.01, 0.05],
#                          'max_depth': [3, 4, 5], 'reg_lambda': [0, 1.0, 10.0],
#                          'scale_pos_weight': [1, 3, 5]},
#              scoring='roc_auc')

# %%
# Checking Optimal Params_ for round 1
optimal_params.best_params_
# Out:
# {'gamma': 0,
#  'learning_rate': 0.1,
#  'max_depth': 3,
#  'reg_lambda': 10.0,
#  'scale_pos_weight': 1}

# %%
# Round 2
param_grid={
            'max_depth':[3], # from round 1
            'learning_rate':[0.1,0.5,1],
            'gamma':[0], #from 1
            'reg_lambda':[10,20,100],
            'scale_pos_weight':[3] # from 1
               }

from sklearn.model_selection import GridSearchCV
optimal_params=GridSearchCV(estimator=xgb.XGBClassifier(objective='binary:logistic',seed=42,subsample=0.9,colsample_bytree=0.5),
                            param_grid=param_grid,
                            scoring='roc_auc',
                            verbose=0,
                            n_jobs=10,
                            cv=3
                            )

optimal_params.fit(x_train,y_train,verbose=False,early_stopping_rounds=10,eval_metric='auc',eval_set=[(x_test,y_test)])
# Out:
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(colsample_bytree=0.5, seed=42,
#                                      subsample=0.9),
#              n_jobs=10,
#              param_grid={'gamma': [0], 'learning_rate': [0.1, 0.5, 1],
#                          'max_depth': [3], 'reg_lambda': [10, 20, 100],
#                          'scale_pos_weight': [3]},
#              scoring='roc_auc')

# %%
# Checking Optimal Params_ for round 2
optimal_params.best_params_
# Out:
# {'gamma': 0,
#  'learning_rate': 0.1,
#  'max_depth': 3,
#  'reg_lambda': 10,
#  'scale_pos_weight': 3}

# %% [raw]
# # Finally we got all above values

# %% [markdown]
# # Final Model building

# %%
import xgboost as xgb
clf_xgb=xgb.XGBClassifier(objective='binary:logistic',seed=42,gamma=0,learn_rate=0.1,max_depth=3,reg_lambda=10,scale_pos_weight=3,subsample=0.9,colsample_bytree=0.5) 
clf_xgb.fit(x_train,y_train,verbose=True,early_stopping_rounds=10,eval_metric='aucpr',eval_set=[(x_test,y_test)])
# Out:
# [0]	validation_0-aucpr:0.509066
# Will train until validation_0-aucpr hasn't improved in 10 rounds.
# [1]	validation_0-aucpr:0.581691
# [2]	validation_0-aucpr:0.605982
# [3]	validation_0-aucpr:0.609191
# [4]	validation_0-aucpr:0.61469
# [5]	validation_0-aucpr:0.611965
# [6]	validation_0-aucpr:0.608364
# [7]	validation_0-aucpr:0.61257
# [8]	validation_0-aucpr:0.611106
# [9]	validation_0-aucpr:0.614009
# [10]	validation_0-aucpr:0.617582
# [11]	validation_0-aucpr:0.615645
# [12]	validation_0-aucpr:0.617466
# [13]	validation_0-aucpr:0.61805
# [14]	validation_0-aucpr:0.618883
# [15]	validation_0-aucpr:0.62827
# [16]	validation_0-aucpr:0.628739
# [17]	validation_0-aucpr:0.629625
# [18]	validation_0-aucpr:0.629683
# [19]	validation_0-aucpr:0.642053
# [20]	validation_0-aucpr:0.642052
# [21]	validation_0-aucpr:0.643298
# [22]	validation_0-aucpr:0.643143
# [23]	validation_0-aucpr:0.644647
# [24]	validation_0-aucpr:0.645193
# [25]	validation_0-aucpr:0.64433
# [26]	validation_0-aucpr:0.645789
# ...

# %%
# Checking performance on testing dataset
#plotting Confusion Matrix for test dataset
from sklearn.metrics import plot_confusion_matrix
plot_confusion_matrix(clf_xgb, x_test, y_test,values_format='d',display_labels=['Did not Left','Left'])

# %%
921/(921+373)
# Out:
# 0.7117465224111282

# %%
381/(86+381)
# Out:
# 0.815845824411135

# %% [raw]
# # Now it is performed better than first
